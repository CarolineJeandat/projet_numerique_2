# %% [markdown]
# # Projet numérique 2 : les équations de Lotka-Volterra
# ### Caroline Jeandat, Colombel Paul

# %%
# %matplotlib inline

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\paulc\miniconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\paulc\miniconda3\lib\site-packages (from scipy) (1.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import log
import autograd
import matplotlib.animation as animation
from scipy.optimize import newton as newt


from IPython.display import display
from IPython.display import HTML
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

# %%
def display_contour(f, x, y, levels):
    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)
    fig, ax = plt.subplots()
    contour_set = plt.contour(
        X, Y, Z, colors="grey", linestyles="dashed", 
        levels=levels 
    )
    ax.clabel(contour_set)
    plt.grid(True)
    plt.xlabel("$x_1$") 
    plt.ylabel("$x_2$")
    plt.gca().set_aspect("equal")

# %%
alpha = 2/3
beta = 4/3
gamma = 1.0
delta = 2.0

# %% [markdown]
# $$ \left\{
#     \begin{array}{ll}
#         \frac{dx_1}{dt} = x_1.(\alpha − \beta.x_2) \\
#         \frac{dx_2}{dt} = -x_2.(\gamma - \delta.x_1)
#     \end{array}
#     \right. $$
#
# $$ dx_1 = x_1(t+dt) - x_1(t) $$
# $$ dx_2 = x_2(t+dt) - x_2(t) $$

# %%
xmax = 1
ymax = 1
dx = 0.1
dy = 0.1
Nx = int(xmax/dx)+1
Ny = int(ymax/dy)+1

dt = dx

# %% [markdown]
# #### Question 1

# %% [markdown]
# Interprétation des termes des équations :
# - $\alpha$ : coefficient de reproduction des proies
# - $\beta$ : taux de mortalité des proies, à cause des prédateurs
# - $\gamma$ : mortalité des prédateurs en l'absence de proies
# - $\delta$ : coefficient de reproduction des prédateurs grâce à la présence de proies

# %% [markdown]
# Les points d'équilibre vérifient :
# $$ \left\{
#     \begin{array}{ll}
#         x_1.(\alpha − \beta.x_2) = 0 \\
#         -x_2.(\gamma - \delta.x_1) = 0
#     \end{array}
#     \right. $$
#
#
#
# Les points d'équilibre sont donc :
# - $(0,0)$ qui est instable. En effet, on étudie la fonction $f : (x_1,x_2) \mapsto (x_1.(\alpha - \beta .x_2), -x_2.(\gamma - \delta . x_1))$ qui est continûment différentiable (par théorèmes généraux). Sa matrice jacobienne en $(0,0)$ est
#
# $$J_f(0,0) =
#  \begin{pmatrix}
#      \alpha & 0 \newline
#      0 & -\delta
#   \end{pmatrix}
# $$
#
# dont les valeurs propres sont $\alpha > 0$ et $-\delta < 0$. $(0,0)$ est donc instable par théorème de lien entre stabilité et stabilité du linéarisé tangent.
# - $\overline{x} = (\frac{\gamma}{\delta}, \frac{\alpha}{\beta})$ dont on ne peut pour l'instant rien dire avec le théorème ci-dessus. En effet, avec la même fonction $f$ :
#
# $$J_f(\frac{\gamma}{\delta}, \frac{\alpha}{\beta}) =
#  \begin{pmatrix}
#      0 & -\frac{\beta\gamma}{\delta} \newline
#      \frac{\alpha\delta}{\beta} & 0
#   \end{pmatrix}
# $$
#
# dont les valeurs propres sont des imaginaires purs : $+i\sqrt{\alpha\gamma}$ et $-i\sqrt{\alpha\gamma}$.

# %% [markdown]
# #### Question 2

# %%
X = np.linspace(0, xmax, Nx)
Y = np.linspace(0, ymax, Ny)
X, Y = np.meshgrid(X, Y)
U = (alpha-beta*Y)*X
V = (delta*X-gamma)*Y

# %%
# champ de vecteur
plt.quiver(X,Y,U,V);

# %%
# portrait de phase
plt.streamplot(X,Y,U,V);

# %% [markdown]
# D'après le champ de vecteurs et le portrait de phase, les solutions ont l'air d'être périodiques ou du moins elles tournent autour d'un point.

# %% [markdown]
# #### Question 3

# %% [markdown]
# Soit $(x_1,x_2)$ une solution des équations de Lotka-Vloterra, initialisée à $t_0$ dans $\mathbb{R}_+^* \times \mathbb{R}_+^*$. On montre que sur son ensemble de définition, cette solution reste dans $\mathbb{R}_+^* \times \mathbb{R}_+^*$.
#
# Par l'absurde, supposons qu'il existe un temps $t' > t_0$ tq $x_1(t') \leq 0$ ou $x_2(t') \leq 0$. Par continuité de la solution, et puisque $x_1(t_0) > 0$ et $x_2(t_0) > 0$, il existe $t_1$ tq $x_1(t_1) = 0$ ou $x_2(t_1) = 0$.
# - si $(x_1(t_1), x_2(t_1)) = (0,y)$, on vérifie que $(t \mapsto 0, t \mapsto y.e^{\gamma(t_1 - t)})$ est solution. De plus, $f : (a,b) \mapsto (a.(\alpha - \beta .b), -b.(\gamma - \delta . a))$ est différentiable et
#
# $$J_f(a,b) =
#  \begin{pmatrix}
#      \alpha - \beta b & -\beta a \newline
#      \delta b & \delta a - \gamma
#   \end{pmatrix}
# $$
#
# ce qui assure sa continue différentiabilité par rapport à (a,b). Cette solution est unique par théorème de Cauchy-Lipschitz. On a alors $x_1(t_0) = 0$, ce qui contredit les hypothèses.
# - de la même manière, si $(x_1(t_1), x_2(t_1)) = (y,0)$, l'unique solution est $(t \mapsto y.e^{\gamma(t_1 - t)}, t \mapsto 0)$, ce qui mène à une contradiction.
#
# On a bien montré le résultat.

# %% [markdown]
# #### Question 4

# %% [markdown]
# On étudie la fonction $H : (x_1,x_2) \mapsto \delta x_1 - \gamma \ln(x_1) + \beta x_2 - \alpha \ln(x_2)$ le long des solutions
# initialisées dans $\mathbb{R}_+^* \times \mathbb{R}_+^*$ :
#
# $$\frac{dH}{dt} = \delta \frac{dx_1}{dt} - \frac{\gamma}{x_1} \frac{dx_1}{dt} + \beta \frac{dx_2}{dt} - \frac{\alpha}{x_2} \frac{dx_2}{dt} = 0$$
#
# $H$ est constante, donc la solution $(x_1, x_2)$ est bornée, et est donc définie sur $\mathbb{R}$.

# %% [markdown]
# #### Question 5

# %%
def H(x1, x2):
    return delta*x1 - gamma*log(x1) + beta*x2 - alpha*log(x2)

# %%
display_contour(
    H, 
    x=np.linspace(0.1, xmax, Nx), 
    y=np.linspace(0.1, ymax, Ny), 
    levels=10
)

# %% [markdown]
# $\overline{x}$ est au centre des lignes de niveaux ; c'est un minimum de $H$. Les solutions tournent autour de $\overline{x}$, sur les courbes de niveaux de $H$.  $\overline{x}$ est un point d'équilibre stable, puisque toute solution initialisée proche de $\overline{x}$ suit une courbe de niveau de $H$, et on observe graphiquement que les courbes de niveaux encerclent $\overline{x}$ sans s'en éloigner (à plus d'un certain epsilon).

# %% [markdown]
# #### Question 6

# %%
def solve_euler_explicit(f, x0, dt, t0, tf):
    N = int((tf-t0)/dt) + 1
    t = np.linspace(t0,tf,N)
    x = [x0]
    for i in range(N-1):
        x.append(x[i] + dt*f(t[i],x[i]))
    return t, np.array(x)

# %%
# %%capture

def test(x,t):
    return np.exp(x)
tr = np.linspace(0,10,500)
xr = np.exp(tr)

fig = plt.figure()
line, = plt.plot([],[])
lineref, = plt.plot(tr,xr)
plt.xlim(0, 6)
plt.ylim(0,150)

def init():
    line.set_data([],[])
    return line,

def animate(i): 
    t, x = solve_euler_explicit(test,0,1/(i+0.5),0,10)
    line.set_data(t,x)

    return line, lineref,

ani = animation.FuncAnimation(fig, animate,init_func=init, frames=10,blit =True, interval=250, repeat=True)

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0d04bd26790247bbbfe43f7614efb174">
#   <div class="anim-controls">
#     <input id="_anim_slider0d04bd26790247bbbfe43f7614efb174" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0d04bd26790247bbbfe43f7614efb174.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim0d04bd26790247bbbfe43f7614efb174.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim0d04bd26790247bbbfe43f7614efb174.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim0d04bd26790247bbbfe43f7614efb174.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim0d04bd26790247bbbfe43f7614efb174.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim0d04bd26790247bbbfe43f7614efb174.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim0d04bd26790247bbbfe43f7614efb174.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim0d04bd26790247bbbfe43f7614efb174.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim0d04bd26790247bbbfe43f7614efb174.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim0d04bd26790247bbbfe43f7614efb174.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select0d04bd26790247bbbfe43f7614efb174"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0d04bd26790247bbbfe43f7614efb174"
#              >
#       <label for="_anim_radio1_0d04bd26790247bbbfe43f7614efb174">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0d04bd26790247bbbfe43f7614efb174"
#              checked>
#       <label for="_anim_radio2_0d04bd26790247bbbfe43f7614efb174">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0d04bd26790247bbbfe43f7614efb174"
#              >
#       <label for="_anim_radio3_0d04bd26790247bbbfe43f7614efb174">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0d04bd26790247bbbfe43f7614efb174";
#     var slider_id = "_anim_slider0d04bd26790247bbbfe43f7614efb174";
#     var loop_select_id = "_anim_loop_select0d04bd26790247bbbfe43f7614efb174";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/d3fzzAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAuCElEQVR4nO3dd5xdVb3+8c93espMeplJJwnpyQAhdARDBwk94Yoi5XK96pUi\
# Kqg/Ea8oKFL0KvdGQKNSEpoJUiSE3klI771NkplkkqmZds76/bFPkkmYVGZm7X3meb9eee1z9jln\
# fAYn82TvvfZa5pxDREQkalJ8BxARETkSKjAREYkkFZiIiESSCkxERCJJBSYiIpGkAhMRkUhSgYmI\
# SCSpwEREJJJUYCIiEkkqMBERiSQVmI

# %% [markdown]
# On voit çi dessus la convergence du schéma Euler explicite lorsque dt tend vers 0 (les courbes se raprochent de la courbe épaisse rouge qui est la solution analytique).
#
# pour visualiser graphiquement l'odre de convergence on peut prendre le logarithme de la différence entre la solution numérique et analytique ainsi :
#
# $$ log(\| x_{j}-x(t_j) \| ) \leq log(cste) + ordre * log(dt)$$

# %% [markdown]
# #### Question 7

# %%
def LotkaVolterra(t,x):
    x1 = x[0]
    x2 = x[1]
    return np.array([x1*(alpha-beta*x2) , -x2*(gamma-delta*x1)])

# %%
t,x = solve_euler_explicit(LotkaVolterra,np.array([1,1]),0.01,0,500)

# %%
plt.plot(t,x);

# %% [markdown]
# En temps long, on observe que la solution obtenue avec la méthode d'Euler explicite diverge. Cette résolution ne correspond pas à la réalité, puisqu'on a montré en question 4 que les solutions n'explosaient pas en temps fini.

# %%
N = x.shape[0]
proies = np.array([x[i][0] for i in range(N)])
pred = np.array([x[i][1] for i in range(N)])

# %%
h = H(proies, pred)
plt.plot(t,h);

# %% [markdown]
# La fonction $H$ le long de la solution obtenue grâce à Euler explicite n'est pas constante dans le temps, alors qu'elle l'est le long d'une solution exacte. La méthode d'Euler explicite diverge en temps fini.

# %% [markdown]
# #### Question 8

# %% [markdown]
# Schéma d'Euler implicite :

# %%
def solve_euler_implicit_bis(f, x0, dt, t0, tf, itermax=100):
    N = int((tf-t0)/dt) + 1
    t = np.linspace(t0,tf,N)
    x = [x0]
   
    
    for i in range(N-1):
        def solve_x_suiv(y):
            return y - x[i] - dt*f(t[i+1],y)
        
        x_suivant = newt(solve_x_suiv, x[i],maxiter=itermax)
        x.append(x_suivant)
    
    return t,np.array(x)

# %% [markdown]
# On le teste sur des fonctions connues :

# %%
# %%capture
fig = plt.figure()
line, = plt.plot([],[])
lineref, = plt.plot(np.linspace(0,10,500),np.exp(tr))
plt.xlim(0, 6)
plt.ylim(0,150)

def init():
    line.set_data([],[])
    return line,

def animate(i): 
    t, x = solve_euler_implicit_bis(test,0,1/(i+0.5),0,10)
    line.set_data(t,x)

    return line, lineref,

ani = animation.FuncAnimation(fig, animate,init_func=init, frames=10,blit =True, interval=250, repeat=True)

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9797e4542e2941dca267b46d53600b5e">
#   <div class="anim-controls">
#     <input id="_anim_slider9797e4542e2941dca267b46d53600b5e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9797e4542e2941dca267b46d53600b5e.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim9797e4542e2941dca267b46d53600b5e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim9797e4542e2941dca267b46d53600b5e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim9797e4542e2941dca267b46d53600b5e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim9797e4542e2941dca267b46d53600b5e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim9797e4542e2941dca267b46d53600b5e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim9797e4542e2941dca267b46d53600b5e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim9797e4542e2941dca267b46d53600b5e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim9797e4542e2941dca267b46d53600b5e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim9797e4542e2941dca267b46d53600b5e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select9797e4542e2941dca267b46d53600b5e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9797e4542e2941dca267b46d53600b5e"
#              >
#       <label for="_anim_radio1_9797e4542e2941dca267b46d53600b5e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9797e4542e2941dca267b46d53600b5e"
#              checked>
#       <label for="_anim_radio2_9797e4542e2941dca267b46d53600b5e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9797e4542e2941dca267b46d53600b5e"
#              >
#       <label for="_anim_radio3_9797e4542e2941dca267b46d53600b5e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9797e4542e2941dca267b46d53600b5e";
#     var slider_id = "_anim_slider9797e4542e2941dca267b46d53600b5e";
#     var loop_select_id = "_anim_loop_select9797e4542e2941dca267b46d53600b5e";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/d3fzzAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAt30lEQVR4nO3deXhV1b3/8fc3AwkBEqYAgTAKMkQGEamIWmdxROsAtrZOLbf3\
# dhCtttr2Vtv789a2WrWDvZerVmqtgDjhWBVnrQPIPM8QEkggkBEynfX7Yx9CxKCASdbZ53xez8Oz\
# z9nnHPzkkeSTvffaa5lzDhERkbBJ8h1ARETkSKjAREQklFRgIiISSiowEREJJRWYiIiEkgpMRERC\
# SQUmIiKhpAITEZFQUoGJiEgoqcBERC

# %% [markdown]
# On observe bien la convergenge du schéma implicite

# %%
t,x = solve_euler_implicit_bis(LotkaVolterra,np.array([1,1]),0.01,0,500)

# %%
plt.plot(t,x);

# %%
N = x.shape[0]
proies = np.array([x[i][0] for i in range(N)])
pred = np.array([x[i][1] for i in range(N)])

# %%
h = H(proies, pred)
plt.plot(t,h);

# %% [markdown]
# H ne reste pas constant non plus sur le schéma Euler implicite. Il n'est pas convenable.

# %% [markdown]
# #### Question 9

# %% [markdown]
# On étudie les équations suivantes :
#
# $$ \left\{
#     \begin{array}{ll}
#         \frac{dx_1}{dt} = x_1.(\alpha − \beta.x_2) - u_1(x_1,x_2).(H(x_1,x_2) - H_0) \\
#         \frac{dx_2}{dt} = -x_2.(\gamma - \delta.x_1) - u_2(x_1,x_2).(H(x_1,x_2) - H_0)
#     \end{array}
#     \right. $$
#
# où $H_0 = H(x_1(0),x_2(0))$ et $u : \mathbb{R}^2 \mapsto \mathbb{R}^2$ est continûment différentiable.
#
# Si $(x_1, x_2)$ est solution des équations de Lotka-Volterra, alors $H$ est constante le long de $(x_1(t), x_2(t))$, et donc $\forall t, H(x_1(t),x_2(t)) - H_0 = 0$. $(x_1,x_2)$ est alors aussi solution des équations ci-dessus.
#
# Réciproquement si $(x_1, x_2)$ est solution de ce système, la solution $(y_1, y_2)$ des equations de Lokta-voltera telle que $(y_1(0), y_2(0))=(x_1(0), x_2(0))$ convient aussi : les termes en plus des equations de lokta-voltera sont nuls car $H(y_1(0),y_2(0)) = H_0$ et $H$ est constant car il est évalué sur une trajectoire de lokta-voltera.

# %% [markdown]
# #### Question 10

# %% [markdown]
# Pour $(x_1,x_2)$ solution du système, $u$ continûment différentiable :
#
# $\frac{d}{dt}(H(x(t)) - H_0) = \delta \frac{dx_1}{dt} - \frac{\gamma}{x_1} \frac{dx_1}{dt} + \beta \frac{dx_2}{dt} - \frac{\alpha}{x_2} \frac{dx_2}{dt}$
# $$= -(H(x_1,x_2) - H_0).((\delta - \frac{\gamma}{x_1}).u_1(x_1,x_2) + (\beta - \frac{\alpha}{x_2}).u_2(x_1,x_2))$$

# %% [markdown]
# Or on a $\nabla H(x(t)) = (\delta - \frac{\gamma}{x_1}, \beta - \frac{\alpha}{x_2})$.
#
# En choisissant $u:(x_1,x_2) \mapsto k.(\delta - \frac{\gamma}{x_1}, \beta - \frac{\alpha}{x_2})$, on a alors :
#
# $$\frac{d}{dt}(H(x(t)) - H_0) = -k\|\nabla H(x(t))\|^2.(H(x(t))-H_0)\,[1]$$

# %% [markdown]
# Supposons que $x$ reste à une distance strictement positive de $\overline{x}$. Ainsi, $\exists c' > 0$ tq $\forall t$, $\|x(t) - \overline{x}\| \geq c' $..
#
# De plus $\exists c'' > 0$ tel que $\forall t, \space c'' \| x(t)-\overline{x}\|_{\infty } \geq \|x(t) - \overline{x}\| \geq c'$
#
# On remarque que : $\nabla H(x(t)) = (\delta( 1 -\frac{\overline{x}}{x_1}), \beta(1 - \frac{\overline{x}}{x_2}))$
#
# soit $t$ fixé, on a:
#
# $$\| \nabla H(x(t)) \| \geq \| \nabla H(x(t)) \|_{\infty} $$ comme $x$ est borné, on nomme sa borne en norme infinie $x_{max}$.
#
# ainsi :
# $$\| \nabla H(x(t)) \| \geq \| \frac{\delta}{x_1}( x_1-\overline{x_1}),\frac{\beta}{x_2}( x_2-\overline{x_2}) \|_{\infty} \geq \| \frac{\delta}{x_{max}}( x_1-\overline{x_1}),\frac{\beta}{x_{max}}( x_2-\overline{x_2}) \|_{\infty} \space \geq K\| x(t)-\overline{x}\|_{\infty }$$ avec $K > 0$
#
# ainsi : en posant $ c = Kc''$
#
# $$\forall t,\space \frac{d}{dt}(H(x(t)) - H_0) \leq -kc^2.(H(x(t))-H_0)$$
#
# on s'est placé dans le cas $(H(x(t)) - H_0) > 0$ si on est dans le cas strictement négatif on reproduit le même raisonnement en inversant les inégalités en commencant par celle çi dessus. En effet $H-H_0$ est de signe constant (Théorème de Cauchy à l'equation différentielle $[1]$ car la solution nulle convient donc une solution non nulle ne peut pas la croiser).

# %% [markdown]
# on pose $\forall t,\space g(t) = \frac{d}{dt}(H(x(t)) - H_0) + A.(H(x(t))-H_0)\space[*] $ avec $A>0$  on a pour tout $t$, $g(t) \leq 0$
#
# la relation $[*]$ peut s'interpréter comme une equation différentielle en $H-H_0$ dont on connaît la forme générale des solutions :
#
# $$\forall t, \, (H-H_0)(t)= e^{-At}(\space Cste +  \int_{0}^{t} g(u)\,  \mathrm{d}u\space) \leq Cste.e^{-At} $$
#
# on traite de manière similaire le cas négatif et dans tous les cas on a :
# $$\forall t,\,\lvert(H-H_0)(t)\rvert\, \leq \, Cste.e^{-At}$$
#
# d'où $H$ converge exponentiellement vers $H_0$ lorsque $t$ tend vers $+\infty$

# %% [markdown]
# #### Question 11

# %% [markdown]
# Le long des solutions du système de la question 9, $H(x(t))$ tend exponentionnelement vers $H(x(0))$, ce qui assure qu'à partir d'un certain temps, $H$ est quasiment constante dans le temps. De plus, les solutions de ce système et les solutions des équations de Lotka-Volterra sont identiques (si les conditions de la question 9 sont remplies).
#
# Pour assurer la stabilité de $H$ dans le schéma d'Euler, on peut donc utiliser ce système au lieu des équations de prédation initiales, en choisissant $u:(x_1,x_2) \mapsto k.(\delta - \frac{\gamma}{x_1}, \beta - \frac{\alpha}{x_2})$ contiûment différentiable.

# %% [markdown]
# Avec l'égalité de la question 10, on a au premier orde en $dt$ :
#
# $$ H(x^{j+1})-H_0 = (H(x^j)-H_0).(1 - k.dt.\|\nabla H(x^j)\|^2) $$

# %% [markdown]
# Pour $x$ à une distance strictement positive de $\overline{x}$, on a $\nabla H(x) \ne 0$. Quand $dt$ tend vers 0 à $k$ fixé, H devient constante. Ansi, plus $k$ est grand, moins $H$ est stable.
